# %% [markdown]
# 1. Прочитать файлы .seg_Y1 и .seg_B2, которые содержат разметку на слова и звуки для корпуса CORPRES
# 2. Использовать данные разметки, чтобы проверить:
# 2.1. [Закон Ципфа](https://en.wikipedia.org/wiki/Zipf%27s_law) для букв
# 2.2. Закон Ципфа для звуков
# 2.3. Закон Ципфа для слов
# 2.4. [Закон Хипса](https://en.wikipedia.org/wiki/Heaps%27_law) для слов
# 3. Для этого нарисовать графики, которые демонстрировали бы выполнение или невыполнение закона, с помощью библиотеки matplotlib (не является встроенной)

# %% [markdown]
# https://matplotlib.org/stable/tutorials/introductory/pyplot.html

# %%
import matplotlib.pyplot as plt
plt.plot(range(10)) # числа от 0 до 9
plt.show()

# %%
xx = list(range(-5, 6))
yy = [x ** 2 for x in xx]
plt.plot(xx, yy) # квадраты чисел от -5 до 5
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Parabola")
plt.show()

# %% [markdown]
# 4. Организовать все графики на одной картинке с помощью функции subplot()
# 5. Сохранить её с помощью метода savefig()
# 6. (\*) Придумать, какие данные можно извлечь из разметки, построить соответствующие графики.
